# %%
# Weight of cats 6 samples (6 cats)
cats = [15, 20, 18, 12, 8, 9]

# Weight of dogs 6 samples (6 dogs)
dogs = [17, 22, 19, 16, 9, 10]

# %%
import numpy as np

# %%
print(np.mean(cats))
print(np.mean(dogs))
# Out:
# 13.666666666666666
# 15.5

# %%
# Weight of cats 6 samples (6 cats)
cats = [15, 20, 18, 12, 8, 9]

# Weight of dogs 4 samples (4 dogs)
dogs = [17, 22, 9, 10]

# %%
print(np.mean(cats))
print(np.mean(dogs))
# Out:
# 13.666666666666666
# 14.5

# %%
# Imbalanced Data

# %%
# How to deal with imbalanced data

# %%
# 1. Reducing the number of samples (Removing the some samples)

# %%
# 2. You can manipulate // add the missing values with respect to mean or median

# %%
# Imputing -> Removing // Adding samples to the dataset

# %%
import pandas as pd

# %%
df = pd.read_excel('dogcats.xls')

# %%
df
# Out:
#     S.No Labels  Heights  Weights  Breed            color
# 0      1    Dog       10        9    1.0            black
# 1      2    Dog       20        8    1.0            white
# 2      3    Dog       18        5    3.0  black and white
# 3      4    Dog       17       11    NaN       dark brown
# 4      5    Dog       16       12    NaN              NaN
# 5      6    Dog       10        6    NaN              NaN
# 6      7    Dog       11        8    NaN            white
# 7      8    Cat       22        9    NaN              NaN
# 8      9    Cat       13       17    2.0              NaN
# 9     10    Cat       17       20    3.0       dark brown
# 10    11    Cat       18       21    2.0            white
# 11    12    Cat       19       22    NaN            white
# 12    13    Cat       20       14    NaN              NaN
# 13    14    Cat       21       16    NaN              NaN

# %%
colordic = {'white':0, 'black':1, 'dark brown':2}

# %%
dogs = 7
cats = 7

# %%
Remove the features .. when 50% data is missing

# Analysis deals only with height and width

# %%
df = pd.read_excel('dogcats.xls')

# %%
df
# Out:
#     S.No Labels  Heights  Weights  Breed            color
# 0      1    Dog       10        9    1.0            black
# 1      2    Dog       20        8    1.0            white
# 2      3    Dog       18        5    3.0  black and white
# 3      4    Dog       17       11    NaN       dark brown
# 4      5    Dog       16       12    NaN              NaN
# 5      6    Dog       10        6    NaN              NaN
# 6      7    Dog       11        8    NaN            white
# 7      8    Cat       22        9    NaN              NaN
# 8      9    Cat       13       17    2.0            black
# 9     10    Cat       17       20    3.0       dark brown
# 10    11    Cat       18       21    2.0            white
# 11    12    Cat       19       22    NaN            white
# 12    13    Cat       20       14    NaN            black
# 13    14    Cat       21       16    NaN              NaN

# %%
# Impute the data 
Accuracy != 100%

99.9%
# Missing data..

# %%
df = pd.read_excel('dogcats.xls')

# %%
df
# Out:
#     S.No Labels  Heights  Weights  Breed            color
# 0      1    Dog     10.0      9.0    1.0            black
# 1      2    Dog     20.0      8.0    1.0            white
# 2      3    Dog      NaN      NaN    3.0  black and white
# 3      4    Dog     17.0     11.0    NaN       dark brown
# 4      5    Dog     16.0     12.0    NaN              NaN
# 5      6    Dog     10.0      6.0    NaN              NaN
# 6      7    Dog     11.0      8.0    NaN            white
# 7      8    Cat      NaN      9.0    NaN              NaN
# 8      9    Cat     13.0     17.0    2.0            black
# 9     10    Cat     17.0     20.0    3.0       dark brown
# 10    11    Cat      NaN      NaN    2.0            white
# 11    12    Cat     19.0     22.0    NaN            white
# 12    13    Cat     20.0     14.0    NaN            black
# 13    14    Cat     21.0      NaN    NaN              NaN

# %%
Data imbalanced

Breed feature

Dog: 6 samples (3 features)
Cat: 4 samples (3 features)
    
#     Nan 
    
#     Data Synthesis -> Data Augmentation ..

# Extreme values -> Outliers -> Size of the data.

# %%
# Balancing the data

# %%
Regression, Logistic, Statistics

# %%
# Qualitative data
Color 
 {white, brown}
    
Car data 
-> Model = {Teslas:0, Tesla z:1}

# %%
# Find unique = {data}

# %%
df = pd.read_excel('dogcats.xls')

# %%
# df Interval valued
# Out:
#     S.No Labels  Heights  Weights  Breed            color         age
# 0      1    Dog     10.0      9.0    1.0            black      1 to 2
# 1      2    Dog     20.0      8.0    1.0            white      2 to 3
# 2      3    Dog      NaN      NaN    3.0  black and white    1.5 to 2
# 3      4    Dog     17.0     11.0    NaN       dark brown      2 to 3
# 4      5    Dog     16.0     12.0    NaN              NaN    2.5 to 3
# 5      6    Dog     10.0      6.0    NaN              NaN    3 to 3.5
# 6      7    Dog     11.0      8.0    NaN            white    1.5 to 2
# 7      8    Cat      NaN      9.0    NaN              NaN      2 to 3
# 8      9    Cat     13.0     17.0    2.0            black    2.5 to 3
# 9     10    Cat     17.0     20.0    3.0       dark brown    3 to 3.5
# 10    11    Cat      NaN      NaN    2.0            white    1 to 1.5
# 11    12    Cat     19.0     22.0    NaN            white    1.7 to 2
# ...

# %%
df = pd.read_excel('dogcats.xls')

# %%
# df
# Out:
#     S.No Labels  Heights  Weights  Breed            color         age  \
# 0      1    Dog     10.0      9.0    1.0            black      1 to 2
# 1      2    Dog     20.0      8.0    1.0            white      2 to 3
# 2      3    Dog      NaN      NaN    3.0  black and white    1.5 to 2
# 3      4    Dog     17.0     11.0    NaN       dark brown      2 to 3
# 4      5    Dog     16.0     12.0    NaN              NaN    2.5 to 3
# 5      6    Dog     10.0      6.0    NaN              NaN    3 to 3.5
# 6      7    Dog     11.0      8.0    NaN            white    1.5 to 2
# 7      8    Cat      NaN      9.0    NaN              NaN      2 to 3
# 8      9    Cat     13.0     17.0    2.0            black    2.5 to 3
# 9     10    Cat     17.0     20.0    3.0       dark brown    3 to 3.5
# 10    11    Cat      NaN      NaN    2.0            white    1 to 1.5
# 11    12    Cat     19.0     22.0    NaN            white    1.7 to 2
# ...

# %%
food-time;

Feature 5-6, feature 6-8  feature 10-12 fature 12-14   feature 15-17 fature 17-20   
1                1               1        1             0                1

# %%
# Multi valued - interval type of data
# 11:15 we can come back

# %%
# Feature selection
# Feature reduction

# %%
# Feature reduction:
#     Overlapping of data with respect to histogram / Normal Distribution

# %%
# Imagine 100 features
30 features having overlaps

# .. A sample can be represented of 70 features

# %%
# Iris data

# %%
Mean of all features with species

Setosa
mean of sepalwidth 
mean of sepalength
mean of petalwidth
mean of petalheight

Virginica

Setosa
mean of sepalwidth 
mean of sepalength
mean of petalwidth
mean of petalheight

versicolor

Please find the average

# %%
df = pd.read_csv('iris.csv')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
//Separate the data

# %%
# setosa = np.array((mean_sepallength, mean_sepalwidth, mean_petallength, mean_petalwidth))
setosa = np.array((1, 2, 3, 4))
versicolor = np.array((4, 5, 6, 7))
virginica = np.array((4, 5, 6, 8))

# %%
# All features included

# %% [markdown]
# dist1 = np.linalg.norm(setosa-versicolor)

# %%
dist1 = np.linalg.norm(setosa-versicolor)

dist1 = 3.2
# Out:
# 6.0

# %%
dist2 = np.linalg.norm(setosa-virginica)
dist2 = 4.75
# Out:
# 6.557438524302

# %%
dist3 = np.linalg.norm(versicolor-virginica)
dist3 = 1.62
# Out:
# 1.0

# %%
# Mean  value 
# All features
dist1 = 3.2
dist2 = 4.75
dist3 = 1.62

# %%
# Remove sepal_width
dist1 = 3.14 // .06
dist2 = 4.73 // .02
dist3 = 1.61 // .01

# %%
# Remove sepal_length
dist1 = 3.07 // .13
dist2 = 4.48 // .27
dist3 = 1.48 // .24

# %%
# Remove petal_length
dist1 = 2.2 
dist2 = 1.56
dist3 = 0.97

# %%
# Remove petal_width
dist1 = 3.02
dist2 = 4.40
dist3 = 1.5

# %%
# Pattern Recognition 

Feature Selection or Feature Reduction:
    
#     Most discriminating features
# petal_length


#  Less discriminating features 

# sepal_width

# %%
# Holistical approach
a new sample = {5.3, 3.2, .5, 0.3} // Setosa or Versicolor or virginica

# %%
Some features are not necessary / Less important

# %%
xser = np.sin(np.arange(50))
plt.scatter(xser, np.arange(50))

setosa = data[data['species'] == 'setosa']

# %%
 avarage setosa = q = {f11, f12, f13, f14} 
    
 avarage versicolor = p= {f21, f22, f23, f24} 

avarage versicolor = {f1, f2, f3, f4} 


distance between setosa_versicolor = sqrt((f11 - f21)^2 + (f12 - f22)^2 + (f13 - f23)^2 + (f14 - f24)^2)

# %%
# Euclidean distance
# Cityblock distance
# Cos Distance
# Chessboard distance

  setosa_versicolor = 
    
    
    # Mean  value 
# All features
setosa_versicolor = dist1 = 3.2
setosa_virginica dist2 = 4.75
versicolor_versicolor dist3 = 1.62

# %%
Pythogorean theorem:
    
    -> Euclidean Distance

# %%
# Number of features to be removed 
# Number of featured to be considered = Parametric approach

# Threshold = T < remove 

# Application

T = 3.2

Dataset = 500 features /

150 features

remaining features not much discrimination

Volumenous data = 100000 data

5 hrs to 2 days

1 hrs

# %%
setosa = df[df['species'] == 'setosa']

# %%
setosa
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 0            5.1          3.5           1.4          0.2  setosa
# 1            4.9          3.0           1.4          0.2  setosa
# 2            4.7          3.2           1.3          0.2  setosa
# 3            4.6          3.1           1.5          0.2  setosa
# 4            5.0          3.6           1.4          0.2  setosa
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa
# 11           4.8          3.4           1.6          0.2  setosa
# 12           4.8          3.0           1.4          0.1  setosa
# ...

# %%
import seaborn as sns

# %%
sns.scatterplot(data=setosa, x="sepal_length", y="petal_length")
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
sns.scatterplot(data=setosa, x="sepal_length", y="petal_width")
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_width'>

# %%
sns.scatterplot(data=setosa, x="petal_width", y="petal_length")
# Out:
# <AxesSubplot:xlabel='petal_width', ylabel='petal_length'>

# %%
sns.scatterplot(data=setosa, x="petal_width", y="petal_length")
# Out:
# <AxesSubplot:xlabel='petal_width', ylabel='petal_length'>

# %%
sns.scatterplot(data=df, x="petal_width", y="species")
# Out:
# <AxesSubplot:xlabel='petal_width', ylabel='species'>

# %%
iris = sns.load_dataset("iris")
g = sns.PairGrid(iris)
g.map(sns.scatterplot)

# %%
g = sns.PairGrid(iris, hue="species")
g.map_diag(sns.histplot)
g.map_offdiag(sns.scatterplot)
g.add_legend()

# %%
tel = pd.read_csv('telecom_churn.csv')

# %%
tel
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
# Check for missing values
# How many area codes

# %%
area_415 = tel[tel['Area code'] == 415]
area_415
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 4       OK              75        415                Yes              No
# 7       MO             147        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3326    OH              96        415                 No              No
# 3327    SC              79        415                 No              No
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
# Can you count number of calls from the area 415

# %%
Area = 415

1655 => International plan 150
  
    From 150 record -> Total day minutes
    
                     -> Total charges 

Other areas

1. Compute total areas

Area    Total Calls         International Plan       TotalDay minutes             Total day Charges
415      1655               150                        m                             mxc
408

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
# None

# %%
print(df.columns)
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Comment this if the data visualisations doesn't work on your side
# %matplotlib inline

plt.style.use('bmh')

# %%
df = pd.read_csv('train.csv')
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
# df.count() does not include NaN values
df2 = df[[column for column in df if df[column].count() / len(df) >= 0.3]]
del df2['Id']
print("List of dropped columns:", end=" ")
for c in df.columns:
    if c not in df2.columns:
        print(c, end=", ")
print('\n')
df = df2
# Out:
# List of dropped columns: Id, Alley, PoolQC, Fence, MiscFeature,

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 76 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1460 non-null   int64
#  1   MSZoning       1460 non-null   object
#  2   LotFrontage    1201 non-null   float64
#  3   LotArea        1460 non-null   int64
#  4   Street         1460 non-null   object
#  5   LotShape       1460 non-null   object
#  6   LandContour    1460 non-null   object
#  7   Utilities      1460 non-null   object
#  8   LotConfig      1460 non-null   object
#  9   LandSlope      1460 non-null   object
#  10  Neighborhood   1460 non-null   object
#  11  Condition1     1460 non-null   object
#  12  Condition2     1460 non-null   object
#  13  BldgType       1460 non-null   object
#  14  HouseStyle     1460 non-null   object
#  15  OverallQual    1460 non-null   int64
#  16  OverallCond    1460 non-null   int64
# ...

# %%
pd. na

# %%
print(df['SalePrice'].describe())
plt.figure(figsize=(9, 8))
sns.distplot(df['SalePrice'], color='g', bins=100, hist_kws={'alpha': 0.4});
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64
# /home/amarnath/.local/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
list(set(df.dtypes.tolist()))
# Out:
# [dtype('O'), dtype('int64'), dtype('float64')]

# %%
df_num = df.select_dtypes(include = ['float64', 'int64'])
df_num.head()
# Out:
#    MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0          60         65.0     8450            7            5       2003
# 1          20         80.0     9600            6            8       1976
# 2          60         68.0    11250            7            5       2001
# 3          70         60.0     9550            7            5       1915
# 4          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  ...  WoodDeckSF  \
# 0          2003       196.0         706           0  ...           0
# 1          1976         0.0         978           0  ...         298
# 2          2002       162.0         486           0  ...           0
# 3          1970         0.0         216           0  ...           0
# 4          2000       350.0         655           0  ...         192
#
#    OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  \
# ...

# %%
df_num_corr = df_num.corr()['SalePrice'][:-1] # -1 because the latest row is SalePrice
golden_features_list = df_num_corr[abs(df_num_corr) > 0.5].sort_values(ascending=False)
print("There is {} strongly correlated values with SalePrice:\n{}".format(len(golden_features_list), golden_features_list))
# Out:
# There is 10 strongly correlated values with SalePrice:
# OverallQual     0.790982
# GrLivArea       0.708624
# GarageCars      0.640409
# GarageArea      0.623431
# TotalBsmtSF     0.613581
# 1stFlrSF        0.605852
# FullBath        0.560664
# TotRmsAbvGrd    0.533723
# YearBuilt       0.522897
# YearRemodAdd    0.507101
# Name: SalePrice, dtype: float64

# %%
for i in range(0, len(df_num.columns), 5):
    sns.pairplot(data=df_num,
                x_vars=df_num.columns[i:i+5],
                y_vars=['SalePrice'])

# %%
import operator

individual_features_df = []
for i in range(0, len(df_num.columns) - 1): # -1 because the last column is SalePrice
    tmpDf = df_num[[df_num.columns[i], 'SalePrice']]
    tmpDf = tmpDf[tmpDf[df_num.columns[i]] != 0]
    individual_features_df.append(tmpDf)

all_correlations = {feature.columns[0]: feature.corr()['SalePrice'][0] for feature in individual_features_df}
all_correlations = sorted(all_correlations.items(), key=operator.itemgetter(1))
for (key, value) in all_correlations:
    print("{:>15}: {:>15}".format(key, value))
# Out:
#    KitchenAbvGr: -0.1392006921778576
#        HalfBath: -0.08439171127179902
#      MSSubClass: -0.08428413512659509
#     OverallCond: -0.07785589404867797
#          YrSold: -0.028922585168736813
#    BsmtHalfBath: -0.02883456718548182
#        PoolArea: -0.014091521506356765
#    BsmtFullBath: 0.011439163340408606
#          MoSold: 0.046432245223819446
#       3SsnPorch: 0.06393243256889088
#     OpenPorchSF: 0.08645298857147718
#         MiscVal: 0.08896338917298921
#      Fireplaces: 0.12166058421363891
#       BsmtUnfSF: 0.16926100049514173
#    BedroomAbvGr: 0.18093669310848806
#      WoodDeckSF: 0.1937060123752066
#      BsmtFinSF2: 0.19895609430836594
#   EnclosedPorch: 0.24127883630117497
#     ScreenPorch: 0.2554300795487841
#         LotArea: 0.2638433538714051
#    LowQualFinSF: 0.30007501655501323
#     LotFrontage: 0.35179909657067737
#      MasVnrArea: 0.43409021975689227
#      BsmtFinSF1: 0.47169042652357296
#     GarageYrBlt: 0.4863616774878596
# ...

# %%
corr = df_num.drop('SalePrice', axis=1).corr() # We already examined SalePrice correlations
plt.figure(figsize=(12, 10))

sns.heatmap(corr[(corr >= 0.5) | (corr <= -0.4)], 
            cmap='viridis', vmax=1.0, vmin=-1.0, linewidths=0.1,
            annot=True, annot_kws={"size": 8}, square=True);
