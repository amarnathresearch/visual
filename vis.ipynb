# %%
import pandas as pd

# %%
# !pip3 install seaborn

# %%
df = pd.read_csv('iris.csv')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
tips = df

# %%
import seaborn as sns

# %%
tips = sns.load_dataset("tips")
tips.head(50)
# Out:
#     total_bill   tip     sex smoker  day    time  size
# 0        16.99  1.01  Female     No  Sun  Dinner     2
# 1        10.34  1.66    Male     No  Sun  Dinner     3
# 2        21.01  3.50    Male     No  Sun  Dinner     3
# 3        23.68  3.31    Male     No  Sun  Dinner     2
# 4        24.59  3.61  Female     No  Sun  Dinner     4
# 5        25.29  4.71    Male     No  Sun  Dinner     4
# 6         8.77  2.00    Male     No  Sun  Dinner     2
# 7        26.88  3.12    Male     No  Sun  Dinner     4
# 8        15.04  1.96    Male     No  Sun  Dinner     2
# 9        14.78  3.23    Male     No  Sun  Dinner     2
# 10       10.27  1.71    Male     No  Sun  Dinner     2
# 11       35.26  5.00  Female     No  Sun  Dinner     4
# 12       15.42  1.57    Male     No  Sun  Dinner     2
# 13       18.43  3.00    Male     No  Sun  Dinner     4
# 14       14.83  3.02  Female     No  Sun  Dinner     2
# 15       21.58  3.92    Male     No  Sun  Dinner     2
# ...

# %%
sns.kdeplot(
    data=df, x="sepal_length", hue="species",
    cumulative=False, common_norm=False, common_grid=True,
)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='Density'>

# %%
sns.kdeplot(
    data=df, x="sepal_width", hue="species",
    cumulative=False, common_norm=False, common_grid=True,
)
# Out:
# <AxesSubplot:xlabel='sepal_width', ylabel='Density'>

# %%
sns.kdeplot(
    data=df, x="petal_width", hue="species",
    cumulative=False, common_norm=False, common_grid=True,
)
# Out:
# <AxesSubplot:xlabel='petal_width', ylabel='Density'>

# %%
sns.kdeplot(
    data=df, x="petal_length", hue="species",
    cumulative=False, common_norm=False, common_grid=True,
)
# Out:
# <AxesSubplot:xlabel='petal_length', ylabel='Density'>

# %%
setosa = df[df['species'] == 'setosa']

versicolor = df[df['species'] == 'versicolor']
versicolor
virginica = df[df['species'] == 'virginica']
virginica
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 100           6.3          3.3           6.0          2.5  virginica
# 101           5.8          2.7           5.1          1.9  virginica
# 102           7.1          3.0           5.9          2.1  virginica
# 103           6.3          2.9           5.6          1.8  virginica
# 104           6.5          3.0           5.8          2.2  virginica
# 105           7.6          3.0           6.6          2.1  virginica
# 106           4.9          2.5           4.5          1.7  virginica
# 107           7.3          2.9           6.3          1.8  virginica
# 108           6.7          2.5           5.8          1.8  virginica
# 109           7.2          3.6           6.1          2.5  virginica
# 110           6.5          3.2           5.1          2.0  virginica
# 111           6.4          2.7           5.3          1.9  virginica
# 112           6.8          3.0           5.5          2.1  virginica
# ...

# %%
sns.histplot(data=setosa, x="sepal_length")
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='Count'>

# %%
sns.histplot(data=df, x="sepal_width")
# Out:
# <AxesSubplot:xlabel='sepal_width', ylabel='Count'>

# %%
sns.histplot(data=versicolor, x="sepal_length")
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='Count'>

# %%
sns.histplot(data=virginica, x="sepal_length")
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='Count'>

# %%
sns.kdeplot(
    data=tips, x="total_bill", hue="time",
    cumulative=True, common_norm=False, common_grid=True,
)

# %%
sns.kdeplot(data=tips, x="total_bill", hue="time")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
import numpy as np
import matplotlib.pyplot as plt
data = np.random.randint(20, 100, 6)
plt.pie(data)
circle = plt.Circle( (0,0), 0.7, color='white')
p=plt.gcf()
p.gca().add_artist(circle)
plt.show()

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip")
# Linear Regression
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
ax = sns.boxplot(x=tips["total_bill"])

# %%
penguins = sns.load_dataset("penguins")
penguins
sns.pairplot(penguins)

# %%
sns.set_theme()
uniform_data = np.random.rand(10, 12)
ax = sns.heatmap(uniform_data)

# %%
# !pip3 install sklearn
# Out:
# ...
#      |████████████████████████████████| 25.8 MB 189 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 306 kB 4.1 MB/s eta 0:00:01
# ...
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1315 sha256=371ebb0815fd41887bddb97f311f14b37f07ad6490e6123e41ff223c8572e056
#   Stored in directory: /home/amarnath/.cache/pip/wheels/22/0b/40/fd3f795caaa1fb4c6cb738bc1f56100be1e57da95849bfc897
# Successfully built sklearn
# ...

# %%
# from sklearn.linear_model import LogisticRegression
# from sklearn.metrics import confusion_matrix
# #Fit the model
# logreg = LogisticRegression(C=1e5)
# logreg.fig(X,y)
# #Generate predictions with the model using our X values
# y_pred = logreg.predict(X)
# #Get the confusion matrix
# cf_matrix = confusion_matrix(y, y_pred)

cf_matrix = [[5, 10],[7, 3]]
print(cf_matrix)
# Out:
# [[5, 10], [7, 3]]

# %%
sns.heatmap(cf_matrix, annot=True)
# Out:
# <AxesSubplot:>
